# %%
import json
import chardet

# %%
with open("./cctv_coverted/하라문교차로_20210412075826_0017436.json",'r')as f:
    json_data = json.load(f)

# %%
json_data
# Out:
# {'version': '5.2.1',
#  'flags': {},
#  'shapes': [{'label': '일반차량',
#    'points': [[88, 301], [150, 361]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[228, 312], [271, 365]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[0, 386], [59, 475]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[184, 373], [234, 452]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[283, 307], [327, 362]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': 'police',
#    'points': [[171, 295], [221, 346]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
# ...

# %%
json_data.values()
# Out:
# dict_values(['5.2.1', {}, [{'label': '일반차량', 'points': [[88, 301], [150, 361]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[228, 312], [271, 365]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[0, 386], [59, 475]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[184, 373], [234, 452]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[283, 307], [327, 362]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': 'police', 'points': [[171, 295], [221, 346]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[277, 167], [330, 253]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}, {'label': '일반차량', 'points': [[244, 366], [304, 44
# ...

# %%
json_data.keys()
# Out:
# dict_keys(['version', 'flags', 'shapes', 'imagePath', 'imageData', 'imageHeight', 'imageWidth'])

# %%
json_data
# Out:
# {'version': '5.2.1',
#  'flags': {},
#  'shapes': [{'label': '일반차량',
#    'points': [[88, 301], [150, 361]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[228, 312], [271, 365]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[0, 386], [59, 475]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[184, 373], [234, 452]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': '일반차량',
#    'points': [[283, 307], [327, 362]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
#    'flags': {}},
#   {'label': 'police',
#    'points': [[171, 295], [221, 346]],
#    'group_id': None,
#    'description': '',
#    'shape_type': 'rectangle',
# ...

# %%
def detect_encoding(file_path):
    with open(file_path, 'rb') as f:
        raw_data = f.read()
        result = chardet.detect(raw_data)
        return result['encoding']

# %%
file_path = "./cctv_coverted/하라문교차로_20210412075826_0017436.json"
encoding = detect_encoding(file_path)
print(encoding)
# Out:
# utf-8

# %%
with open(r"C:\Users\Smart\Desktop\code\blood_supply_0001.json",'r')as f:
    raw_data = json.load(f)

# %%
raw_data.keys()
# Out:
# dict_keys(['version', 'flags', 'shapes', 'imagePath', 'imageData', 'imageHeight', 'imageWidth'])

# %%
file_path = r"C:\Users\Smart\Desktop\code\blood_supply_0001.json"
encoding = detect_encoding(file_path)
print(encoding)
# Out:
# ascii

# %%
raw_data.values()
# Out:
# dict_values(['5.2.1', {}, [{'label': 'blood_car', 'points': [[404.375, 423.75], [1134.375, 967.5]], 'group_id': None, 'description': '', 'shape_type': 'rectangle', 'flags': {}}], 'blood_supply_0001.jpg', '...', 1080, 1920])

# %%
with open(r"C:\Users\Smart\Desktop\datas\emergency_vehicle\emergency_labeling_data\ambulance\labeling_data\P_211115_P_04_M14_01_01_S_0001.json",'r')as f:
    json_data = json.load(f)

# %%
json_data.keys()
# Out:
# dict_keys(['rawDataInfo', 'sourceDataInfo', 'learningDataInfo'])

# %%
json_data.values()
# Out:
# dict_values([{'rawDataID': 'P_211115_P_04_M14_01_01_S', 'copyrighter': '㈜미디어그룹사람과숲', 'resolution': '1920*1080', 'date': '2021-11-15', 'StartTime': '11:07:00', 'EndTime': '11:13:00', 'length': 360, 'season': 'Autumn', 'weather': 'Sunny', 'precip': 0, 'temp': 10, 'condition': 'Stop', 'fps': 30, 'fStop': 'F/13', 'exposureTime': '10/600', 'ISO': 200, 'LargeCategoryId': '특수차', 'MediumCategoryId': '승합특수형(특수차)', 'SmallCategoryId': '구급차', 'fileExtension': 'mp4'}, {'sourceDataID': 'P_211115_P_04_M14_01_01_S_0001', 'fileExtension': 'jpg'}, {'path': None, 'LearningDataId': 'P_211115_P_04_M14_01_01_S_0001', 'fileExtension': 'json', 'objects': [{'annotation': 'cuboid', 'front': {'points': [{'x': 667.3757546688346, 'y': 266.38101074417705}, {'x': 1089.9168118175046, 'y': 266.38101074417705}, {'x': 1089.9168118175046, 'y': 937.0406018829592}, {'x': 667.3757546688346, 'y': 831.1460709497709}]}, 'back': {'points': [{'x': 1087.719598603477, 'y': 288.38017508957586}, {'x': 1312.904711760709, 'y': 288.3
# ...

# %%
json_data["learningDataInfo"]["objects"]
# Out:
# [{'annotation': 'cuboid',
#   'front': {'points': [{'x': 667.3757546688346, 'y': 266.38101074417705},
#     {'x': 1089.9168118175046, 'y': 266.38101074417705},
#     {'x': 1089.9168118175046, 'y': 937.0406018829592},
#     {'x': 667.3757546688346, 'y': 831.1460709497709}]},
#   'back': {'points': [{'x': 1087.719598603477, 'y': 288.38017508957586},
#     {'x': 1312.904711760709, 'y': 288.38017508957586},
#     {'x': 1312.904711760709, 'y': 625.4108877932952},
#     {'x': 1087.7195986034772, 'y': 608.4805529577869}]}},
#  {'annotation': 'bbox',
#   'coords': {'tl': {'x': 674, 'y': 279},
#    'tr': {'x': 1320, 'y': 279},
#    'bl': {'x': 674, 'y': 865},
#    'br': {'x': 1320, 'y': 865}},
#   'left': 674,
#   'top': 279,
#   'width': 646,
#   'height': 586,
#   'angle': 0}]

# %%
json_data["learningDataInfo"]["objects"]["annotation"]["coords"]["tl"]["x"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 json_data["learningDataInfo"]["objects"]["annotation"]["coords"]["tl"]["x"]
#
# TypeError: list indices must be integers or slices, not str

# %%
with open("./10545581-1-T_p821cb593-69ac-4694-910b-607c37f4771d0_mosaic.mp4_33.json",'r')as f:
    data = json.load(f)
